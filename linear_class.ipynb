# %%
# %reload_ext autoreload
# %autoreload 2
import opt
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# #### Generate the dataset

# %%
# Generate N random points
N = 1000
split = 0.8
pts = np.random.rand(N, 2)

# Split into training and testing datasets
np.random.shuffle(pts)
train, test = {}, {}
train['x'], test['x'] = pts[:int(N*split),:], pts[int(N*split):,:]

# Generate categories with nonlinear decision boundary
x1, x2 = 0.2, 0.8
decision_bound = lambda x: -10*(x-x1)*(x-x2)

mask = pts[:, 1] > decision_bound(pts[:, 0])
pos = pts[mask]
neg = pts[~mask]
train['y'], test['y'] = mask[:int(N*split)].astype(int), mask[int(N*split):].astype(int)

# %%
# Visualize dataset
plt.scatter(*pos.T)
plt.scatter(*neg.T)
xs = np.arange(x1, x2, 0.01)
plt.plot(xs, decision_bound(xs), 'r')

# %% [markdown]
# #### Generate random linear and nonlinear resistive networks

# %%
# Parameters
nodes = 10
density = 5/(nodes-1) # limit average degree to 5
denser = 0.8
diode_thresh = 0.2 # on average each node has 1 diode
mask = np.random.uniform(0, 0.5, (nodes, nodes))
mask = mask + mask.T
con = mask < density
dense = mask < denser
diodes = mask < diode_thresh

# %%
# Create the linear network -- initialize random (symmetric) resistor values and apply 
# the connectivity mask
tmp = np.random.rand(nodes, nodes)
lin_network = (tmp + tmp.T) * dense

# %%
# Create the nonlinear network -- initialize random (symmetric) resistor values and apply 
# the connectivity mask. Then, apply the diode mask by assigning random directions to each diode.
relu_network = (tmp + tmp.T) * (dense & ~(diodes | diodes.T))
diodes_dir = tmp < tmp.T
relu_network += diodes_dir * diodes

# %% [markdown]
# #### Train both networks

# %%
epochs=50
node_cfg = np.concatenate((np.random.permutation([1, 1, -1] + [0]*(nodes-4)), [0]))

# %%
# Train linear network
trained_lin = opt.train(lin_network, train['x'][:50,], train['y'][:50,None], node_cfg, epochs=epochs, nu=0.5)

# %%
# Train nonlinear network
trained_relu = opt.train(relu_network, train['x'][:50,], train['y'][:50,None], node_cfg, epochs=epochs, nu=0.5)

# %% [markdown]
# #### Compare the networks

# %%
# Evaluate accuracy on training data
lin_outputs = opt.inference(trained_lin, train['x'], node_cfg)[:, np.argwhere(node_cfg < 0)].squeeze()
relu_outputs = opt.inference(trained_relu, train['x'], node_cfg)[:, np.argwhere(node_cfg < 0)].squeeze()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# /Users/lancemathias/Projects/circuit_sim/nonlinear_class.ipynb Cell 14 in <module>
#       <a href='vscode-notebook-cell:/Users/lancemathias/Projects/circuit_sim/nonlinear_class.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> # Evaluate accuracy on training data
#       <a href='vscode-notebook-cell:/Users/lancemathias/Projects/circuit_sim/nonlinear_class.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> lin_outputs = opt.inference(trained_lin, train['x'], node_cfg)[:, np.argwhere(node_cfg < 0)].squeeze()
# ----> <a href='vscode-notebook-cell:/Users/lancemathias/Projects/circuit_sim/nonlinear_class.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> relu_outputs = opt.inference(trained_relu, train['x'], node_cfg)[:, np.argwhere(node_cfg < 0)].squeeze()
#
# File ~/Projects/circuit_sim/opt.py:80, in inference(mat, xs, node_cfg)
#      77 bounds[in_nodes, 0] = xs[i]
#      78 bounds[in_nodes, 1] = xs[i]
# ---> 80 sol = solve(mat, bounds)
#      81 if not sol.success:
#      82     return sol.message
#
# File ~/Projects/circuit_sim/opt.py:23, in solve(mat, bounds)
#      21 obj = better_obj(mat)
#      22 x0 = np.random.random(bounds.shape[0])
# ---> 23 return minimize(obj, x0, bounds=bounds)
#
# File /opt/homebrew/lib/python3.9/site-packages/scipy/optimize/_minimize.py:681, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     678     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     679                              **options)
#     680 elif meth == 'l-bfgs-b':
# --> 681     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     682                            callback=callback, **options)
#     683 elif meth == 'tnc':
#     684     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     685                         **options)
#
# File /opt/homebrew/lib/python3.9/site-packages/scipy/optimize/_lbfgsb_py.py:308, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     305     else:
#     306         iprint = disp
# --> 308 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     309                               bounds=new_bounds,
#     310                               finite_diff_rel_step=finite_diff_rel_step)
#     312 func_and_grad = sf.fun_and_grad
#     314 fortran_int = _lbfgsb.types.intvar.dtype
#
# File /opt/homebrew/lib/python3.9/site-packages/scipy/optimize/_optimize.py:263, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     259     bounds = (-np.inf, np.inf)
#     261 # ScalarFunction caches. Reuse of fun(x) during grad
#     262 # calculation reduces overall function evaluations.
# --> 263 sf = ScalarFunction(fun, x0, args, grad, hess,
#     264                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     266 return sf
#
# File /opt/homebrew/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:158, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     155     self.f = fun_wrapped(self.x)
#     157 self._update_fun_impl = update_fun
# --> 158 self._update_fun()
#     160 # Gradient evaluation
#     161 if callable(grad):
#
# File /opt/homebrew/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File /opt/homebrew/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File /opt/homebrew/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File /opt/homebrew/lib/python3.9/site-packages/scipy/optimize/_minimize.py:893, in _remove_from_func.<locals>.fun_out(x_in, *args, **kwargs)
#     891 x_out[i_fixed] = x_fixed
#     892 x_out[~i_fixed] = x_in
# --> 893 y_out = fun_in(x_out, *args, **kwargs)
#     894 y_out = np.array(y_out)
#     896 if min_dim == 1:
#
# File ~/Projects/circuit_sim/opt.py:17, in better_obj.<locals>.pwr_dis(x)
#      15 def pwr_dis(x):
#      16     xs = np.repeat(x[:,None], x.shape, 1)
# ---> 17     return np.sum((xs > xs.T).astype(int)*(xs - xs.T)**2*mat)
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('float64'), dtype('<U61')) -> None

# %%
lin_acc = np.count_nonzero((lin_outputs >= 0.5) == train['y']) / lin_outputs.size
relu_acc = np.count_nonzero((relu_outputs >= 0.5) == train['y']) / lin_outputs.size
lin_acc, relu_acc
# Out:
# (0.65625, 0.6575)

# %%
# Visualize the actual results
plt.scatter(*train['x'][train['y'].astype(bool)].T)
plt.scatter(*train['x'][~train['y'].astype(bool)].T)

# %%
# Visualize linear network
plt.scatter(*train['x'][lin_outputs >= 0.5].T)
plt.scatter(*train['x'][lin_outputs < 0.5].T)

# %%
# Visualize relu network
plt.scatter(*train['x'][relu_outputs >= 0.5].T)
plt.scatter(*train['x'][relu_outputs < 0.5].T)

# %% [markdown]
# #### Compare to linear classifier

# %%
cont_ftr = ['x_coord', 'y_coord']
